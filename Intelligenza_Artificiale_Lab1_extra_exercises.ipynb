# %% [markdown]
# Es 1
#
# Write a program that asks the user for the base and height of
# a rectangle. Then print the perimeter and area value
# of the rectangle.

# %%
# compute_perimeter (b, h) function that receives two parameters (base, height) in input and compute the perimeter
def perimeter(b,h):
  return b*2+h*2


# computer_area (b, h) function that receives two parameters (base, height) in input and compute the area
def area(b,h):
  return b*h

# write the instructions to receive in input base and height and call the functions
h=int(input("Inserisci altezza: "))
b=int(input("Inserisci base: "))

print("perimetro: "+str(perimeter(b,h)))
print("area: "+str(area(b,h)))
# Out:
# Inserisci altezza2
# Inserisci base3
# perimetro10
# area6

# %% [markdown]
# Es 2
#
# s = input("What is your name? ")
#
# Print the type of the variable s, the length, the first and last character.

# %%
s = input("What is your name? ")

#Print the type of the variable s, 
print(type(s))
#the length, 
print(len(s))
#the first and last character.
print(s[0])
print(s[-1])
# Out:
# What is your name? michele
# <class 'str'>
# 7
# m
# e

# %% [markdown]
# Es 3
#
# Write a program that asks for two numbers. If the sum of the two
# number exceeds 100, print ``Number too large''

# %%
# ask number x
x=int(input("primo numero: "))
# ask number y
y=int(input("secondo numero: "))
# compute the sum
z=x+y
# verify the condition and add print
if z>100:
  print("Number too large")
else:
  print(z)
# Out:
# primo numero: 3
# secondo numero: 99
# Number too large

# %% [markdown]
# Es 4
# *   Fill an initially empty list with 10 values ​​read from keyboard.
# *   Print the largest and smallest value contained in the list

# %%
# Empty list
l=[]
# Iterate
for i in l:
  print(i)
# Ask for value
for i in range(3):
  x=int(input("Inserisci numero: "))
# Fill
  l.append(x)
# Temp max
max1=0
for i in l:
  if max1<i:
    max1=i
print(max1)
print(str(max(l)))
# Temp min
min1=0
for i in l:
  if min1>i:
    min1=i
print(min1)
print(min(l))
# Iterate and check which is the max and the min
for i in l:
  print(i)
# Out:
# Inserisci numero: 1
# Inserisci numero: 2
# Inserisci numero: 3
# 3
# 3
# 0
# 1
# 1
# 2
# 3

# %% [markdown]
# Es 5
#
# After importing the numpy module create an array
# of 100 random numbers with integer values ​​between 0 and
# 50.
#
# Print all numbers greater than the mean and the
# their location
#
# NB: You find hints in the documentation

# %%
# import the numpy
import numpy as np
# create an array of 100 random numbers between 0 and 50
a=np.random.randint(0, 50,100)
print(a)
# compute the mean
z=np.mean(a)
print(z)
print()
# Print the expected number and the locations
for i in range(len(a)):
  if a[i]>z and a[i]>i:
    print(a[i])
# Out:
# [19 20 40  6 29 30 13  2 33 25 13  7 37 39 40  5 32 37 42 43 40 33  2 21
#  38 42  1 10 33 37  6 30 47 36 34 13  1 31 18 12 26  8 40 12 24 23 39  1
#   5 43 35 19 36 27 36 33 26  6 32 43 33  7 37  7 25 22  3 33 43 10  4 21
#  41 39 12  0 27 37 24 29 16 18 35 23 21 17  7 21  8 15 40 45 37 47  6 47
#  22 46 13 39]
# 24.88
#
# 40
# 29
# 30
# 33
# 25
# 37
# 39
# 40
# 32
# 37
# 42
# 43
# 40
# 33
# 38
# 42
# 33
# 37
# 47
# 36

# %% [markdown]
# Es 6
#
# Write a multiplier function(number_list) that
# given a list of numbers, multiply all of them together and returns the result. If the
# list is empty returns 0.

# %%
# define the function
def function(l):
# check if it is empty
  if len(l)==0: return 0
# multiple the values
  res=1
  for i in l:
    res=res*i
  return res
# define the list
l=[2,3,4,5]
# call the function
print(function(l))
# Out:
# 120

# %% [markdown]
# Es 7
#
# Write a countdown(string) function.
# The function takes a string as a parameter and returns the
# string after making it lowercase all the
# characters and in uppercase only the last character (e.g
# example "abcd" becomes "dcbA"). Also manage the
# empty string case.

# %%
def f(s):
  if s=="": return s
  s=s.lower()
  s1=""
  for i in range(len(s)):
    if i!=len(s)-1:
      s1+=s[i]
    else:
      s1+=s[i].upper()
  return s1

stri="CIAo"
print(f(stri))
# Out:
# ciaO

# %% [markdown]
# Es 8
#
# Write a function frequency(string). The function
# takes a string as a parameter and returns a
# dictionary representing the frequency of each
# character component of the string.
# For example, given a string "ababcc", the
# function returns result {"a": 2, "b": 2, "c":
# 2}.

# %%
def f(s):
  dict={}
  for i in s:
    cont=0
    for j in s:
      if i==j:
        cont=cont+1
    dict[i]=cont
  return dict

str="ababcc"
print(f(str))
# Out:
# {'a': 2, 'b': 2, 'c': 2}
